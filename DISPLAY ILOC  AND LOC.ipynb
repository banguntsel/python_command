# %%
# import panda and numpy
import pandas as pd
import numpy as np

# %%
# Get data frame from csv source and put in df variable 
df = pd.read_csv('https://raw.githubusercontent.com/banguntsel/HomeworkPhyton/master/googleplaystore.csv', encoding='latin1')

# %%
# Display top 4 data.
df.head(4)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# ...

# %%
# display the total rows and columns in the data frame
df.shape
# Out:
# (10841, 13)

# %%
# Display all data frame with category ART_AND_DESIGN and only colum Category, Rating, and Size using loc
# Easy way is to create df_Cat variable as temporary data
df_cat=df[df['Category']=='ART_AND_DESIGN'] 
df_cat.loc[:,['Category','Rating','Size']].head(3)
# Out:
#          Category  Rating  Size
# 0  ART_AND_DESIGN     4.1   19M
# 1  ART_AND_DESIGN     3.9   14M
# 2  ART_AND_DESIGN     4.7  8.7M

# %%
# display Top 3 Row and column Rating 
df_cat.loc[:,'Rating'].head(3)
# Out:
# 0    4.1
# 1    3.9
# 2    4.7
# Name: Rating, dtype: float64

# %%
# display row 0 until row 5 and all column in data frame
df_cat.loc[:4,:]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# display row 0 until row 5 and all column in data frame
df_cat.loc[[0,1,2,3,4],:]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# display row 0 until row 5 and all column in data frame
df_cat.loc[[0,1,2,3,4]]
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
# display row 0 with all column
df_cat.loc[0,:]
# Out:
# App               Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                          ART_AND_DESIGN
# Rating                                                       4.1
# Reviews                                                      159
# Size                                                         19M
# Installs                                                 10,000+
# Type                                                        Free
# Price                                                          0
# Content Rating                                          Everyone
# Genres                                              Art & Design
# Last Updated                                     January 7, 2018
# Current Ver                                                1.0.0
# Android Ver                                         4.0.3 and up
# Name: 0, dtype: object

# %%
# display all rows single column
df_cat.loc[:,'Rating'].head(3)
# Out:
# 0    4.1
# 1    3.9
# 2    4.7
# Name: Rating, dtype: float64

# %%
# display top 3 row with 3 columns
df_cat.loc[:,['Category','Rating','Size']].head(3)
# Out:
#          Category  Rating  Size
# 0  ART_AND_DESIGN     4.1   19M
# 1  ART_AND_DESIGN     3.9   14M
# 2  ART_AND_DESIGN     4.7  8.7M

# %%
# display top 3 row with 3 columns
df_cat.loc[:,'Category':'Size'].head(3)
# Out:
#          Category  Rating Reviews  Size
# 0  ART_AND_DESIGN     4.1     159   19M
# 1  ART_AND_DESIGN     3.9     967   14M
# 2  ART_AND_DESIGN     4.7   87510  8.7M

# %%
# display top 3 row with 3 columns
df_cat.loc[0:2,'Category':'Size'].head(3)
# Out:
#          Category  Rating Reviews  Size
# 0  ART_AND_DESIGN     4.1     159   19M
# 1  ART_AND_DESIGN     3.9     967   14M
# 2  ART_AND_DESIGN     4.7   87510  8.7M

# %%
# all data with index coloring book moana
df_cat[df_cat.App=='Coloring book moana']
# Out:
#                    App        Category  Rating Reviews Size  Installs  Type  \
# 1  Coloring book moana  ART_AND_DESIGN     3.9     967  14M  500,000+  Free
#
#   Price Content Rating                     Genres      Last Updated  \
# 1     0       Everyone  Art & Design;Pretend Play  January 15, 2018
#
#   Current Ver   Android Ver
# 1       2.0.0  4.0.3 and up

# %%
# display top 3 row with genrens column index Art and design 
df_cat[df_cat.Genres=='Art & Design'].head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#   Reviews  Size     Installs  Type Price Content Rating        Genres  \
# 0     159   19M      10,000+  Free     0       Everyone  Art & Design
# 2   87510  8.7M   5,000,000+  Free     0       Everyone  Art & Design
# 3  215644   25M  50,000,000+  Free     0           Teen  Art & Design
#
#       Last Updated         Current Ver   Android Ver
# 0  January 7, 2018               1.0.0  4.0.3 and up
# 2   August 1, 2018               1.2.4  4.0.3 and up
# 3     June 8, 2018  Varies with device    4.2 and up

# %%
# display top 3 row with genrens column index Art and design 
df_cat.loc[df_cat.Genres=='Art & Design',:].head(3)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
#
#   Reviews  Size     Installs  Type Price Content Rating        Genres  \
# 0     159   19M      10,000+  Free     0       Everyone  Art & Design
# 2   87510  8.7M   5,000,000+  Free     0       Everyone  Art & Design
# 3  215644   25M  50,000,000+  Free     0           Teen  Art & Design
#
#       Last Updated         Current Ver   Android Ver
# 0  January 7, 2018               1.0.0  4.0.3 and up
# 2   August 1, 2018               1.2.4  4.0.3 and up
# 3     June 8, 2018  Varies with device    4.2 and up

# %%
# loc colum exclode column 2
# iloc column include column 0
df_cat.iloc[:,0:2].head(3)
# Out:
#                                                  App        Category
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                Coloring book moana  ART_AND_DESIGN
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN

# %%
# loc colum exclode column 3
# iloc column include column 1
df_cat.iloc[1:3,:].head(5)
# Out:
#                                                  App        Category  Rating  \
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
#
#   Reviews  Size    Installs  Type Price Content Rating  \
# 1     967   14M    500,000+  Free     0       Everyone
# 2   87510  8.7M  5,000,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up
# 2               Art & Design    August 1, 2018       1.2.4  4.0.3 and up

# %%
# display top 3 row with column Rating and reviews
df_cat.loc[:,['Rating','Reviews']].head(3)
# Out:
#    Rating Reviews
# 0     4.1     159
# 1     3.9     967
# 2     4.7   87510
